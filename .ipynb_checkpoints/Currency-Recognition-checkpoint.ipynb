# %%
import os

# %%
base_dir = 'data'
train_dir = os.path.join(base_dir, 'train')
test_dir = os.path.join(base_dir, 'test')
train_ten_dir = os.path.join(train_dir, 'ten')
train_fifty_dir = os.path.join(train_dir, 'fifty')
train_hundred_dir = os.path.join(train_dir, 'hundred')
test_ten_dir = os.path.join(test_dir, 'ten')
test_fifty_dir = os.path.join(test_dir, 'fifty')
test_hundred_dir = os.path.join(test_dir, 'hundred')

# %%
from keras.preprocessing.image import ImageDataGenerator
train_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)
# Out:
# Using TensorFlow backend.

# %%
train_generator = train_datagen.flow_from_directory(train_dir, target_size = (150, 150), batch_size = 20, class_mode = 'categorical')
validation_generator = train_datagen.flow_from_directory(test_dir, target_size = (150, 150), batch_size = 20, class_mode = 'categorical')
# Out:
# Found 99 images belonging to 3 classes.
# Found 26 images belonging to 3 classes.

# %%
#generator yields batches indefinitely: so we need to break the iteration loop at some point
for data_batch, labels_batch in train_generator:
    print('data_batch_shape:', data_batch.shape)
    print('labels_batch_shape:', labels_batch.shape)
    break
# Out:
# data_batch_shape: (20, 150, 150, 3)
# labels_batch_shape: (20, 3)

# %%
from keras import layers
from keras import models
model = models.Sequential()

# %%
model.add(layers.Conv2D(32, (3,3), activation = 'relu', input_shape = (150, 150, 3)))
model.add(layers.MaxPooling2D((2,2)))
model.add(layers.Conv2D(64, (3,3), activation = 'relu'))
model.add(layers.MaxPooling2D((2,2)))
model.add(layers.Flatten())
model.add(layers.Dense(100, activation = 'relu'))
model.add(layers.Dense(3, activation = 'softmax'))

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_1 (Conv2D)            (None, 148, 148, 32)      896
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 74, 74, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 72, 72, 64)        18496
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 36, 36, 64)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 82944)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               8294500
# _________________________________________________________________
# dense_2 (Dense)              (None, 3)                 303
# ...

# %%
from keras import optimizers
model.compile(loss = 'binary_crossentropy', optimizer = optimizers.RMSprop(lr=1e-4), metrics = ['acc'])

# %%
history = model.fit_generator(train_generator, steps_per_epoch = 5, epochs = 10, validation_data = validation_generator, validation_steps = 5)
# Out:
# Epoch 1/10
# 5/5 [==============================] - 28s 6s/step - loss: 1.0607 - acc: 0.6061 - val_loss: 0.6385 - val_acc: 0.6667
# Epoch 2/10
# 5/5 [==============================] - 10s 2s/step - loss: 0.5497 - acc: 0.7239 - val_loss: 0.6823 - val_acc: 0.6264
# Epoch 3/10
# 5/5 [==============================] - 10s 2s/step - loss: 0.5420 - acc: 0.7374 - val_loss: 0.6070 - val_acc: 0.6991
# Epoch 4/10
# 5/5 [==============================] - 8s 2s/step - loss: 0.5117 - acc: 0.7811 - val_loss: 0.5075 - val_acc: 0.6207
# Epoch 5/10
# 5/5 [==============================] - 9s 2s/step - loss: 0.4580 - acc: 0.7778 - val_loss: 0.7173 - val_acc: 0.6713
# Epoch 6/10
# 5/5 [==============================] - 8s 2s/step - loss: 0.4101 - acc: 0.8316 - val_loss: 0.5437 - val_acc: 0.6437
# Epoch 7/10
# 5/5 [==============================] - 10s 2s/step - loss: 0.4729 - acc: 0.7778 - val_loss: 0.5167 - val_acc: 0.7824
# Epoch 8/10
# ...

# %%
model.save('recognizer.h5')

# %%
#lack of data so Prediction cannot be done!.. Still doing it one a couple of data by downloading pictures from internet

# %%
from keras.preprocessing.image import load_img, img_to_array, ImageDataGenerator
import matplotlib.pyplot as plt
# %matplotlib inline
img = load_img('download.jpg', target_size = (150, 150))
plt.imshow(img)

# %%
import numpy as np
img = np.array(img)/255
img = np.expand_dims(img, axis = 0)

# %%
img.shape
# Out:
# (1, 150, 150, 3)

# %%
predict = model.predict(img)

# %%
predict
# Out:
# array([[0.30167526, 0.20875196, 0.48957282]], dtype=float32)
